# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
ds.columns
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude', 'zipCode', 'customZone'],
#       dtype='object')

# %%
casa_mas_cara = ds.loc[ds["price"].idxmax()]

print(f"Casa más cara del dataset:")
print(f"Precio: {casa_mas_cara['price']}")
print(f"Dirección: {casa_mas_cara['address']}")
# Out:
# Casa más cara del dataset:
# Precio: 8500000
# Dirección: El Escorial

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
#eliminar casas con valor 0
ds = ds.loc[ds["price"] != 0]
casa_mas_barata = ds.loc[ds["price"].idxmin()]

print(f"Casa más barata del dataset:")
print(f"Precio: {casa_mas_barata['price']}")
print(f"Dirección: {casa_mas_barata['address']}")
# Out:
# Casa más barata del dataset:
# Precio: 600
# Dirección: Berlin, Coslada

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
casa_mas_grande = ds.loc[ds["surface"].idxmax()]
casa_mas_pequeña = ds.loc[ds["surface"].idxmin()]

print(f"Casa más grande del dataset:")
print(f"Superficie: {casa_mas_grande['surface']}")
print(f"Dirección: {casa_mas_grande['address']}")

print(f"Casa más pequeña del dataset:")
print(f"Superficie: {casa_mas_pequeña['surface']}")
print(f"Dirección: {casa_mas_pequeña['address']}")
# Out:
# Casa más grande del dataset:
# Superficie: 249000.0
# Dirección: Sevilla la Nueva
# Casa más pequeña del dataset:
# Superficie: 15.0
# Dirección: Calle Amparo,  Madrid Capital

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
ds = pd.read_csv('assets/real_estate.csv', sep=';')

# %%
cantidad_poblaciones = ds['level5'].nunique()
print(cantidad_poblaciones)

poblaciones = ', '.join(ds['level5'].unique())
print(poblaciones)
# Out:
# 168
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
def contar_NAN(ds):
    conteo = ds.isna().sum()
    return conteo
    

contiene_nan = ds.isna().any()

ds_NaN = pd.concat([contiene_nan,contar_NAN(ds)], axis=1)
ds_NaN.columns = ['Contiene NaN','Cantidad']
ds_NaN
# Out:
#                   Contiene NaN  Cantidad
# Unnamed: 0               False         0
# id_realEstates           False         0
# isNew                    False         0
# realEstate_name           True        10
# phone_realEstate          True       794
# url_inmueble             False         0
# rooms                     True       353
# bathrooms                 True       345
# surface                   True      1250
# price                    False         0
# date                     False         0
# description               True       142
# address                  False         0
# country                  False         0
# level1                   False         0
# level2                   False         0
# level3                   False         0
# level4                    True      6643
# level5                   False         0
# level6                    True     14627
# level7                    True      2277
# level8                    True      8579
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO
new_ds = ds.dropna(axis='columns') #eliminamos aquellas columnas que contienen NaN
ds_filas, ds_columnas = ds.shape #la dimensión del data set se compone de filas y columnas
new_ds_filas, new_ds_columnas = new_ds.shape

print(f"Las dimensiones del dataset original son: {ds_filas} filas y {ds_columnas} columnas")
print(f"Las dimensiones del nuevo dataset son: {new_ds_filas} filas y {new_ds_columnas} columnas")
print(f"La diferencia en dimensiones entre los datasets original versus dataset después de eliminciones son: {ds_filas - new_ds_filas} filas y {ds_columnas - new_ds_columnas} columnas")
# Out:
# Las dimensiones del dataset original son: 15335 filas y 37 columnas
# Las dimensiones del nuevo dataset son: 15335 filas y 25 columnas
# La diferencia en dimensiones entre los datasets original versus dataset después de eliminciones son: 0 filas y 12 columnas

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
ds_arr = ds[ds['level5'] == 'Arroyomolinos (Madrid)']
ds_arr_precio_media = ds_arr['price'].mean()
print(f"El precio promedio en la población de Arroyomolinos (Madrid) es de {round(ds_arr_precio_media,2)} euros")
# Out:
# El precio promedio en la población de Arroyomolinos (Madrid) es de 294541.6 euros

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt
data = ds_arr['price']
plt.figure(figsize = (10, 5))
plt.hist(x=data, bins = 40, alpha = 0.8)
plt.title("Histograma de precios Arroyomolinos (Madrid)")
plt.show()

# %% [markdown]
# Del histograma podemos observar que se distribuye parecido a una campana de Gauss, más cargada a la derecha con valores atipicos bien acotados

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
ds_val = ds[ds['level5'] == 'Valdemorillo']
ds_val_precio_media = ds_val['price'].mean()
print(f"El precio promedio en la población de Valdemorillo es de {round(ds_val_precio_media,0)} euros")

ds_gal = ds[ds['level5'] == 'Galapagar']
ds_gal_precio_media = ds_gal['price'].mean()
print(f"El precio promedio en la población de Galapagar es de {round(ds_gal_precio_media,0)} euros")

print(f'\nLos promedios de Valdemorillo y Galapagar son diferentes (Diferencia={round((ds_val_precio_media - ds_gal_precio_media),0)}€)')
# Out:
# El precio promedio en la población de Valdemorillo es de 363860.0 euros
# El precio promedio en la población de Galapagar es de 360063.0 euros
#
# Los promedios de Valdemorillo y Galapagar son diferentes (Diferencia=3797.0€)

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# le incorporo al data set la variable pps que viene definida por la relación entre el precio y la superficie de cada casa
ds['pps'] =  ds['price']/ds['surface']
ds_val = ds[ds['level5'] == 'Valdemorillo']
ds_gal = ds[ds['level5'] == 'Galapagar']

# calculamos el precio por metro cuadrado promedio
ds_val_pps_media = ds_val['pps'].mean()
print(f"El precio promedio por metro cuadrado en la población de Valdemorillo es de {round(ds_val_pps_media,0)} euros")

ds_gal_pps_media = ds_gal['pps'].mean()
print(f"El precio promedio por metro cuadrado en la población de Galapagar es de {round(ds_gal_pps_media,0)} euros")

print(f'\nLos promedios de Valdemorillo y Galapagar son diferentes (Diferencia={round((ds_val_pps_media - ds_gal_pps_media),0)}€)')
# Out:
# El precio promedio por metro cuadrado en la población de Valdemorillo es de 1318.0 euros
# El precio promedio por metro cuadrado en la población de Galapagar es de 1606.0 euros
#
# Los promedios de Valdemorillo y Galapagar son diferentes (Diferencia=-288.0€)

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
superficie = ds['surface']
precio = ds['price']
plt.xlabel("Superficie")
plt.ylabel("Precio")

plt.scatter(superficie,precio, s=0.8)
plt.xlim(0,1000) # existen valores atipicos en ambas variables, por lo tanto, acotamos la variable superficie a 3000 m2 como máximo para poder observar la relacion entre precio y superficie.
plt.show()

# %% [markdown]
# Podemos concluir que en general a mayor superficie, mayor es el precio del activo

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
cantidad_agencias = ds['realEstate_name'].nunique()
print(f"El dataset contiene {cantidad_agencias} agencias")
# Out:
# El dataset contiene 1821 agencias

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
numero_casas = ds['level5'].value_counts()

print(numero_casas.iloc[[0]])
# Out:
# level5
# Madrid Capital    6643
# Name: count, dtype: int64

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
poblaciones_cs = ['Fuenlabrada','Leganés','Getafe','Alcorcón']
cinturon_sur  = ds[ds['level5'].isin(poblaciones_cs)]

cinturon_sur
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
mediana_cs = cinturon_sur.groupby('level5')['price'].median()


plt.figure(figsize=(10, 6))
mediana_cs.plot(kind='bar', color='skyblue', edgecolor='blue')
plt.title('Media del Precio de Casas del Cinturón Sur')
plt.xlabel("Población")
plt.ylabel('Precio')

plt.show()

# %% [markdown]
# En base a los resultados podemos observar que la mediana entre las problaciones de Alcorcón, Fuenlabrada, Leganés son similares, dentro del rango de 150 mil a 180 mil euros, mientras que en el caso de Getafe, al menos 50% de las casas es superior a 280 mil euros.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
variables_cs = ['price','rooms','surface','bathrooms','pps']
media_cs = cinturon_sur.groupby('level5')[variables_cs].mean()
var_cs = cinturon_sur.groupby('level5')[variables_cs].var()

print(f"Media: {media_cs}")

print(f"Varianza: {var_cs}")
#ds_medvar_cs = pd.concat([media_cs,var_cs],axis=1)
#ds_medvar_cs
# Out:
# Media:                      price     rooms     surface  bathrooms          pps
# level5
# Alcorcón     230071.052632  2.914894  105.913295   1.623656  2239.302480
# Fuenlabrada  177198.021459  3.025974  103.624365   1.445415  1796.729220
# Getafe       265040.500000  3.151724  126.896266   1.865052  2066.314949
# Leganés      208682.010309  2.906736  105.852273   1.518135  2047.503268
# Varianza:                     price     rooms      surface  bathrooms            pps
# level5
# Alcorcón     1.594783e+10  0.933895  4244.323834   0.592735  291547.651085
# Fuenlabrada  4.701021e+09  0.355844  2264.643893   0.353367  163561.898348
# Getafe       2.098267e+10  0.772748  5828.110028   0.658809  550375.106197
# Leganés      1.191394e+10  0.824590  3987.475195   0.553055  225190.658496

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
casa_mas_cara_cs = cinturon_sur.loc[cinturon_sur.groupby('level5')["price"].idxmax()]

print(f"Casas más caras de cada problación del Cinturón Sur:")
print(f"Precio: {casa_mas_cara_cs[['level5','price','address']]}")
# Out:
# Casas más caras de cada problación del Cinturón Sur:
# Precio:             level5    price                                address
# 5585      Alcorcón   950000                               Alcorcón
# 11561  Fuenlabrada   490000  Calle de Paulo Freire, 5, Fuenlabrada
# 2881        Getafe  1050000                                 Getafe
# 10412      Leganés   650000           Avenida Reina Sofía, Leganés

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
cinturon_sur
level5_cs = cinturon_sur[['level5','price']].copy()
level5_cs['precio_norm'] = level5_cs.groupby('level5')['price'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))

#level5_cs

# Crear histograma para cada población
plt.figure(figsize=(10, 6))

# Colores y etiquetas por población
colores = ['red', 'blue', 'green', 'orange']
poblaciones = level5_cs['level5'].unique()

for i, poblacion in enumerate(poblaciones):
    subset = level5_cs[level5_cs['level5'] == poblacion]
    plt.hist(
        subset['precio_norm'],
        bins=50,
        alpha=0.9,
        label=f'Población {poblacion}',
        color=colores[i]
    )

# Personalizar el gráfico
plt.title('Histogramas Normalizados de Precios por Población')
plt.xlabel('Precio Normalizado')
plt.ylabel('Frecuencia')
plt.legend(title="Población")
plt.grid(alpha=0.1)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Del histograma podemos observar que para el caso de la población Getafe los precios no sigue una distribución normal y podemos decir que tiene una doble moda, mientras que los demas parecen seguir una distribución normal en torno a 0,1

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
#ds_get = ds[ds['level5'] == 'Getafe']
#ds_alc = ds[ds['level5'] == 'Alcorcón']

#ds_get_pps = ds_get['pps']
#ds_alc_pps = ds_alc['pps']


colores = ['red', 'blue']
poblaciones = ['Getafe','Alcorcón']

for i, poblacion in enumerate(poblaciones):
    subset = ds[ds['level5'] == poblacion]
    plt.hist(
        subset['pps'],
        bins=30,
        alpha=0.9,
        label=f'Población {poblacion}',
        color=colores[i]
    )

# Personalizar el gráfico
plt.title('Histogramas de precios por metro cuadrado por Población')
plt.xlabel('Precio por metro cuadrado')
plt.ylabel('Frecuencia')
plt.legend(title="Población")
plt.grid(alpha=0.1)

# Mostrar el gráfico
plt.show()

# %%
ds_get = ds[ds['level5'] == 'Getafe']
ds_alc = ds[ds['level5'] == 'Alcorcón']

ds_get_pps = ds_get['pps'].describe()
ds_alc_pps = ds_alc['pps'].describe()

ds_get_alc_pps = pd.concat([ds_get_pps,ds_alc_pps],axis=1)
ds_get_alc_pps.columns = ['Getafe','Alcorcón']

print(ds_get_alc_pps)
# Out:
#             Getafe     Alcorcón
# count   241.000000   173.000000
# mean   2066.314949  2239.302480
# std     741.872702   539.951527
# min       0.000000   604.761905
# 25%    1684.285714  1904.081633
# 50%    1973.333333  2207.792208
# 75%    2628.787879  2472.727273
# max    3827.160494  3698.159509

# %% [markdown]
# Del histograma podemos visualizar que en Getafe existen casas con valor cero, estos datos nulos afectan las medidas de tendencia central.
# Del analisis descriptivo podemos observar que en promedio el costo promedio por metro cuadrado es más barato en Getafe que en Alcorcón.

# %%
ds_get_pps1 = ds_get['pps'][ds_get['pps'] != 0]
ds_get_pps1 = ds_get_pps1.describe()

ds_get1_alc_pps = pd.concat([ds_get_pps1,ds_alc_pps],axis=1)
ds_get1_alc_pps.columns = ['Getafe','Alcorcón']

print(ds_get1_alc_pps)
# Out:
#             Getafe     Alcorcón
# count   229.000000   173.000000
# mean   2174.593462  2239.302480
# std     585.532018   539.951527
# min    1196.666667   604.761905
# 25%    1720.454545  1904.081633
# 50%    2060.606061  2207.792208
# 75%    2643.243243  2472.727273
# max    3827.160494  3698.159509

# %% [markdown]
# Al eliminar los ceros podemos observar que las conclusiones anteriores se mantienen,por lo tanto, en promedio el costo promedio por metro cuadrado es más barato en Getafe que en Alcorcón.

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
cinturon_sur
level5_cs = cinturon_sur[['level5','price','pps']].copy()
level5_cs['precio_norm'] = level5_cs.groupby('level5')['price'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))

#level5_cs

# Crear histograma para cada población
plt.figure(figsize=(10, 6))

# Colores y etiquetas por población
colores = ['red', 'blue', 'green', 'orange']
poblaciones = level5_cs['level5'].unique()

for i, poblacion in enumerate(poblaciones):
    subset = level5_cs[level5_cs['level5'] == poblacion]
    plt.scatter(subset["pps"], subset["precio_norm"], color=colores[i], alpha=0.9, label=poblacion)

# Personalizar el gráfico
plt.title('Grafico de dispersión precio promedio por metro cuadrado de cada Población')
plt.xlabel('Precio Normalizado')
plt.ylabel('Precio por metro cuadrado')
plt.legend(title="Población")
plt.grid(alpha=0.9)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, Marker, MarkerCluster, basemaps

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
mapa = Map(center=(40.4, -3.7), zoom=10, min_zoom=1, max_zoom=20, basemap=basemaps.OpenStreetMap.Mapnik)

# %%
cinturon_sur


colores = {'Fuenlabrada':'red','Alcorcón':'blue','Leganés':'green','Getafe':'orange'}
poblaciones = level5_cs['level5'].unique()
poblaciones

for poblacion in poblaciones:
    marcadores = []
    subset = cinturon_sur[cinturon_sur["level5"] == poblacion]
    
    for _, row in subset.iterrows():
        # Verificar que haya datos de latitud y longitud válidos
        if pd.notna(row["latitude"]) and pd.notna(row["longitude"]):
            marker = Marker(location=(row["latitude"], row["longitude"]), title=poblacion, draggable=False)
            marker.icon_color = colores[poblacion]  # Color asignado según la población
            marcadores.append(marker)
    
    # Crear un cluster de marcadores para la población actual y añadirlo al mapa
    cluster = MarkerCluster(markers=marcadores)
    mapa.add_layer(cluster)

# Mostrar el mapa
mapa
# Out:
# Map(center=[40.4, -3.7], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out…
